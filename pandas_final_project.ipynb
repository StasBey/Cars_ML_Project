# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
features_file = "Resources/data.csv"
features_df = pd.read_csv(features_file)
features_df.head()
# Out:
#         Make     Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0  Chevrolet  Cavalier  2004  regular unleaded      140.0               4.0
# 1     Toyota      ECHO  2003  regular unleaded      108.0               4.0
# 2     Suzuki     Swift  2001  regular unleaded       79.0               4.0
# 3  Chevrolet  Cavalier  2005  regular unleaded      140.0               4.0
# 4     Toyota      ECHO  2004  regular unleaded      108.0               4.0
#
#   Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 0            MANUAL  front wheel drive              2.0             NaN
# 1            MANUAL  front wheel drive              2.0             NaN
# 2            MANUAL  front wheel drive              2.0       Hatchback
# 3            MANUAL  front wheel drive              2.0             NaN
# 4            MANUAL  front wheel drive              2.0             NaN
#
#   Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# ### Transform Features DataFrame

# %%
# Create a filtered dataframe from specific columns
#features_cols = ["License Serial Number", "Premises Name", "County ID Code"]
#features_transformed= premise_df[premise_cols].copy()

# Rename the column headers
features = features_df.rename(columns={"Make": "make", "Model": "model", "Year": "year", "Engine Fuel Type": "fuel_type",
                                                          "Engine HP": "hp",
                                                          "Engine Cylinders": "cylinders",
                                                          "Transmission Type": "transmission",
                                                          "Number of Doors": "doors",
                                                          "Vehicle Size": "size",
                                                          "Vehicle Style": "style",
                                                          "highway MPG": "mpg_highway",
                                                          "city mpg": "mpg_city",
                                                          "Driven_Wheels": "drive",
                                                          "Popularity": "popularity",
                                                        "MSRP": "msrp",
                                                          "Market Category": "category"})

# Clean the data by dropping duplicates and setting the index
#premise_transformed.drop_duplicates("id", inplace=True)
#premise_transformed.set_index("id", inplace=True)

features.head()
# Out:
#         make     model  year         fuel_type     hp  cylinders transmission  \
# 0  Chevrolet  Cavalier  2004  regular unleaded  140.0        4.0       MANUAL
# 1     Toyota      ECHO  2003  regular unleaded  108.0        4.0       MANUAL
# 2     Suzuki     Swift  2001  regular unleaded   79.0        4.0       MANUAL
# 3  Chevrolet  Cavalier  2005  regular unleaded  140.0        4.0       MANUAL
# 4     Toyota      ECHO  2004  regular unleaded  108.0        4.0       MANUAL
#
#                drive  doors   category     size          style  mpg_highway  \
# 0  front wheel drive    2.0        NaN  Compact          Coupe           33
# 1  front wheel drive    2.0        NaN  Compact          Coupe           38
# 2  front wheel drive    2.0  Hatchback  Compact  2dr Hatchback           38
# 3  front wheel drive    2.0        NaN  Compact          Coupe           33
# 4  front wheel drive    2.0        NaN  Compact          Coupe           38
#
#    mpg_city  popularity   msrp
# ...

# %%
features.to_csv(r'cars.csv', index=False)

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:696969@localhost:5432/Cars_Project2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['features', 'emissions', 'vehicles']

# %% [markdown]
# ### Load DataFrames into database

# %%
features.to_sql(name='features', con=engine, if_exists='append', index=False)
#features.to_sql(name='features', con=engine, if_exists='append', index=True)?????
